# %% [markdown]
# # Load scaling efficiency data profiled on NVIDIA H100

# %%
#  Diffusion–request scheduler MILP (two-level objective)
# import Pkg
# Pkg.add("JSON3")
using JSON3
using JuMP
using Gurobi    # swap in Gurobi, CPLEX, ... if available
using Printf

# --------------------------- constants ----------------------
Δ = 0.8                      # slot length in seconds
GPU_COUNTS = [1, 2, 4, 8]    # admissible p
G = 8                        # total GPUs
β = 2                        # slack: may miss β extra jobs in stage-2
seq_len_to_img_size = Dict(256=>(256, 256), 1024=>(512, 512), 2048=>(512, 1024), 4096=>(1024, 1024), 8192=>(1024, 2048), 16384=>(2048, 2048))
# ---------------------- helper functions --------------------
ceil_slots(t) = ceil(Int, t/Δ)
floor_slots(t) = floor(Int, t/Δ)

profile_file = "e2e_scaling_efficiency_bs1.json"
samples = JSON3.read(open(profile_file, "r"))  # JSON3.Array of Objects

# Initialize the raw timing table: profiling[s][p] = best (min) avg_e2e_time
profiling = Dict{Int, Dict{Int, Float64}}()

for sample in samples
    s = sample["seq_len"]                # e.g. 256, 1024, …
    p = sample["mlp_world_size"]         # e.g. 1, 2, 4, 8
    t = sample["avg_e2e_time"]           # e.g. 0.394

    # only consider shapes we care about
    if !(s in keys(seq_len_to_img_size))
        continue
    end

    # ensure the inner dict exists
    if !haskey(profiling, s)
        profiling[s] = Dict{Int,Float64}()
    end

    # record the minimum observed time for (s,p)
    old = get(profiling[s], p, Inf)
    profiling[s][p] = min(old, t)
end

# ——— 2. Quantise into integer slots ———
w = Dict{Int, Dict{Int, Int}}()   # w[s][p] = runtime in slots
r = Dict{Int, Int}()              # r[s]      = single-GPU slots

for (s, inner) in profiling
    ws = Dict{Int, Int}()
    for (p, avg_sec) in inner
        ws[p] = ceil_slots(avg_sec)   # ⌈avg_sec / Δ⌉
    end
    w[s] = ws
    r[s] = ws[1]
end

# Service Level Objectives(SLO)
# deadlines from problem statement (seconds → slots)
SLO = Dict( 256=>2.5, 1024=>3.0, 2048=>4.0, 4096=>7.5, 8192=>12.0, 16384=>30.0 )
d  = Dict(s => ceil_slots(SLO[s]) for s in keys(SLO))


# ——— 3. Build the η‐table ———
sizes = sort(collect(keys(w)))  # e.g. [256,1024,…]
η = Dict{Int, Dict{Int, Float64}}()
for s in sizes
    inner = Dict{Int,Float64}()
    for p in GPU_COUNTS
        if haskey(w[s], p)
            # effective work per slot is r_s / w_{s,p}
            inner[p] = r[s] / w[s][p]
        end
    end
    η[s] = inner
end

# ——— 4. Print penalties ———
println("Scaling penalties (as a percentage of theoretical perfect scaling)")
for s in sizes
    img_shape = seq_len_to_img_size[s]
    for p in GPU_COUNTS
        if haskey(w[s], p)
            # penalty = 1 - (η[s,p] / p)
            penalty = max(0, 1 - (η[s][p] / p))
            pct = round(100*penalty; digits=1)
            println("image shape $(img_shape), p=$p: penalty = $pct%")
        end
    end
end
# Out:
# Scaling penalties (as a percentage of theoretical perfect scaling)
# image shape (256, 256), p=1: penalty = 0.0%
# image shape (256, 256), p=2: penalty = 66.7%
# image shape (256, 256), p=4: penalty = 83.3%
# image shape (256, 256), p=8: penalty = 91.7%
# image shape (512, 512), p=1: penalty = 0.0%
# image shape (512, 512), p=2: penalty = 58.3%
# image shape (512, 512), p=4: penalty = 79.2%
# image shape (512, 512), p=8: penalty = 89.6%
# image shape (512, 1024), p=1: penalty = 0.0%
# image shape (512, 1024), p=2: penalty = 33.3%
# image shape (512, 1024), p=4: penalty = 66.7%
# image shape (512, 1024), p=8: penalty = 83.3%
# image shape (1024, 1024), p=1: penalty = 0.0%
# image shape (1024, 1024), p=2: penalty = 20.0%
# image shape (1024, 1024), p=4: penalty = 42.9%
# image shape (1024, 1024), p=8: penalty = 66.7%
# image shape (1024, 2048), p=1: penalty = 0.0%
# image shape (1024, 2048), p=2: penalty = 13.2%
# image shape (1024, 2048), p=4: penalty = 25.0%
# image shape (1024, 2048), p=8: penalty = 48.4%
# image shape (2048, 2048), p=1: penalty = 0.0%
# image shape (2048, 2048), p=2: penalty = 9.5%
# image shape (2048, 2048), p=4: penalty = 20.8%
# image shape (2048, 2048), p=8: penalty = 32.1%

# %% [markdown]
# # Load request arrival trace

# %%
trace_file = "trace_readable_data_parallel_rate_1.2_cv_0.7_dist_short_seqlen_high.json"
trace_json = JSON3.read(open(trace_file, "r"))

# expand jobs (batch size bs) into individual requests
struct Job
    id::Int
    size::Int
    a::Int       # arrival slot
    d::Int       # deadline slot
    R::Int       # required work
end

jobs = Job[]
job_id = 1
for req in trace_json
    if !haskey(req, "bs")
        continue
    end
    bs   = req["bs"]             # batch size
    size = Int(req["seq_len"])
    a    = floor_slots(req["start_time"])
    for _ = 1:bs
        push!(jobs, Job(job_id, size, a, d[size] + a, r[size]))
        job_id += 1
    end
end
J = 1:length(jobs)
T_max = maximum(j.d for j in jobs)
P     = [p for p in GPU_COUNTS if p ≤ G]

println("Trace has $(length(jobs)) requests.")
println("Max runtime: $T_max slots (=$(@sprintf("%.1f",T_max*Δ)) s)")
# Out:
# Trace has 118 requests.
# Max runtime: 61 slots (=48.8 s)

# %% [markdown]
# # Build and run the ILP model

# %%
function print_job_completion()
    for j in J
        job = jobs[j]
        s    = job.size
        R    = job.R
        shape = seq_len_to_img_size[s]

        # accumulate effective progress until we hit R
        prog = 0.0
        ct   = nothing
        for t in 0:T_max
            for p in P
                prog += η[s][p] * value(x[j,p,t])
            end
            if prog + 1e-9 >= R
                ct = t
                break
            end
        end

        if ct === nothing
            @printf(" • Job %2d (shape %4dx%-4d) DID NOT COMPLETE (prog=%.2f/%.0f)\n",
                    j, shape[1], shape[2], prog, R)
        else
            @printf(" • Job %2d (shape %4dx%-4d) completed at slot %3d (%.2f s)  deadline=%3d  met=%s\n",
                    j, shape[1], shape[2], ct, ct*Δ, job.d, value(f[j])>0.5 ? "yes" : "no")
        end
    end
end


# helper: latest completion slot among finished jobs
function latest_completion_slot(J, jobs_sub, P, x, η, f)
    latest = 0
    for j in J
        # skip unfinished jobs
        if value(f[j]) < 0.5         
            continue
        end
        job = jobs_sub[j]
        prog = 0.0
        for t in job.a:job.d
            for p in P
                prog += η[job.size][p] * value(x[j,p,t])
            end
            if prog + 1e-9 ≥ job.R
                latest = max(latest, t)
                break
            end
        end
    end
    return latest        # slot index
end


function silent_env()  
    redirect_stdout(devnull) do  
        return Gurobi.Env()  
    end  
end  
const gurobi_env = silent_env()  
optimizer_with_env = () -> Gurobi.Optimizer(gurobi_env)

function build_model(jobs::Vector{Job}, num_jobs::Int=length(jobs))
    # slice off the prefix
    jobs_sub = jobs[1:num_jobs]
    J = 1:length(jobs_sub)
    T_max = maximum(job.d for job in jobs_sub)
    P = [p for p in GPU_COUNTS if p ≤ G]

    model = Model(optimizer_with_env)
    set_silent(model)

    # Vars
    @variable(model, x[j in J, p in P, t in 0:T_max], Bin)  # C1, C2, C4 refer to these
    @variable(model, f[j in J], Bin)                       # one var per job

    # (C1) at most one mode per job‐slot
    @constraint(model, [j in J, t in 0:T_max],
        sum(x[j,p,t] for p in P) ≤ 1)

    # (C2) GPU capacity
    @constraint(model, [t in 0:T_max],
        sum(p * x[j,p,t] for j in J, p in P) ≤ G)

    # (C3) no execution before arrival
    for (j, job) in enumerate(jobs_sub)  # j is index into jobs_sub
        for p in P, t in 0:min(job.a-1, T_max)
            fix(x[j,p,t], 0.0; force=true)
        end
    end

    # (C4) progress requirement
    for j in J
        job = jobs_sub[j]
        @constraint(model,
            sum(η[job.size][p] * x[j, p, t] for p in P, t in job.a:job.d)
          ≥ job.R * f[j])
    end

    return model, x, f, jobs_sub, J, P, T_max
end

using Dates  # for high-resolution timing

function solve_with_timelimit!(model; timelimit_s=60)
    # set Gurobi’s time limit (seconds)
    set_optimizer_attribute(model, "TimeLimit", timelimit_s)

    # record start as Float64 seconds
    t0 = time()                                       # :contentReference[oaicite:0]{index=0}
    optimize!(model)
    return time() - t0                               # Float64, in seconds
end


function run_schedule!(
    model, x, f, jobs_sub, J, P, T_max;
    stage1::Bool=false,
    stage2::Bool=false,
    stage3::Bool=false,
    timelimit_s::Real=60,
    verbose::Bool=true
)

    if stage1
        @objective(model, Max, sum(f[j] for j in J))
        solve_time1 = solve_with_timelimit!(model; timelimit_s=timelimit_s)

        Fstar = round(Int, objective_value(model))
        println("Stage 1: met $Fstar / $(length(jobs_sub))  (solver time $(round(solve_time1; digits=2)) s)")

        # compute makespan in slots & seconds
        stage1_slots = latest_completion_slot(J, jobs_sub, P, x, η, f)
        stage1_time     = stage1_slots * Δ
        println("Stage 1 makespan: $(round(stage1_time; digits=2)) s")

        # throughput = #jobs / makespan
        tp1 = Fstar / stage1_time
        println("Stage 1 throughput: $(round(tp1; digits=2)) req/s")
        num_slots = value(sum(p * x[j,p,t] for j in J, p in P, t in 0:T_max))
        println("Stage 1 # of GPU slots used: $(num_slots) ")
    end

    # Minimize make-span (maximize throughput)
    if stage2
        @assert Fstar !== nothing "run stage1 first"
        @constraint(model, sum(f[j] for j in J) ≥ Fstar - β)
        @variable(model, T_fin >= 0, Int)
        # T_fin is the last slot used
        @constraint(model, [j in J, p in P, t in 0:T_max],
            T_fin ≥ t * x[j,p,t])
    
        @objective(model, Min, T_fin)
        
        solve_time2 = solve_with_timelimit!(model; timelimit_s=timelimit_s)
        met2       = round(Int, sum(value(f[j]) for j in J))
        println("Stage 2: met $met2 / $(length(jobs_sub))  (solver time $(round(solve_time2; digits=2)) s)")

        # compute makespan again
        # stage2_slots = latest_completion_slot(J, jobs_sub, P, x, η, f)
        stage2_slots = value(T_fin)
        stage2_time     = stage2_slots * Δ
        println("Stage 2 makespan: $(round(stage2_time; digits=2)) s")

        # throughput
        tp2 = met2 / stage2_time
        println("Stage 2 throughput: $(round(tp2; digits=2)) req/s")
        num_slots = value(sum(p * x[j,p,t] for j in J, p in P, t in 0:T_max))
        println("Stage 2 # of GPU slots used: $(num_slots) ")
    end

    # Minimize GPU slots used
    if stage3
        @constraint(model, T_fin <= stage2_slots)
        @objective(model, Min, sum(p * x[j,p,t] for j in J, p in P, t in 0:T_max))
        solve_time3 = solve_with_timelimit!(model; timelimit_s=timelimit_s)
        met3       = round(Int, sum(value(f[j]) for j in J))
        stage3_slots = value(T_fin)
        stage3_time     = stage3_slots * Δ
        tp3 = met3 / stage3_time

        println("Stage 3 makespan: $(round(stage3_time; digits=2)) s")
        println("Stage 3 throughput: $(round(tp3; digits=2)) req/s")
        println("Stage 3: met $met3 / $(length(jobs_sub))  (solver time $(round(solve_time3; digits=2)) s)")
        num_slots = objective_value(model)
        println("Stage 3 # of GPU slots used: $(num_slots) ")
        
    end 

    if verbose  
        print_job_completion()
end

return nothing
end
# Out:
# run_schedule! (generic function with 1 method)

# %% [markdown]
# # Stage 1 optimization

# %%
model, x, f, jobs_sub, J, P, T = build_model(jobs)
run_schedule!(model, x, f, jobs_sub, J, P, T; stage1=true, stage2=false)
# Out:
# Stage 1: met 72 / 118  (solver time 4.78 s)
# Stage 1 makespan: 44.8 s
# Stage 1 throughput: 1.61 req/s
# Stage 1 # of GPU slots used: 436.0
#  • Job  1 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  2 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  3 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  4 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  5 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job  6 (shape 1024x1024) DID NOT COMPLETE (prog=3.89/16)
#  • Job  7 (shape  256x256 ) completed at slot   5 (4.00 s)  deadline=  5  met=yes
#  • Job  8 (shape  256x256 ) completed at slot   6 (4.80 s)  deadline=  6  met=yes
#  • Job  9 (shape  256x256 ) completed at slot   6 (4.80 s)  deadline=  6  met=yes
#  • Job 10 (shape  256x256 ) completed at slot   6 (4.80 s)  deadline=  6  met=yes
#  • Job 11 (shape  256x256 ) completed at slot   6 (4.80 s)  deadline=  6  met=yes
#  • Job 12 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 13 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 14 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 15 (shape 1024x1024) DID NOT COMPLETE (prog=10.29/16)
#  • Job 16 (shape  256x256 ) completed at slot  10 (8.00 s)  deadline= 10  met=yes
#  • Job 17 (shape  256x256 ) completed at slot   9 (7.20 s)  deadline= 10  met=yes
#  • Job 18 (shape  256x256 ) completed at slot   9 (7.20 s)  deadline= 10  met=yes
#  • Job 19 (shape  256x256 ) completed at slot   9 (7.20 s)  deadline= 10  met=yes
#  • Job 20 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 21 (shape  256x256 ) DID NOT COMPLETE (prog=3.00/4)
#  • Job 22 (shape  512x512 ) DID NOT COMPLETE (prog=2.00/5)
#  • Job 23 (shape  512x512 ) DID NOT COMPLETE (prog=2.00/5)
#  • Job 24 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 25 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 26 (shape  512x512 ) DID NOT COMPLETE (prog=1.00/5)
#  • Job 27 (shape  512x512 ) DID NOT COMPLETE (prog=1.00/5)
#  • Job 28 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 29 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 30 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 31 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 32 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 33 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 34 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 35 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 36 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 37 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 38 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 39 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 40 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 41 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 42 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 43 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 44 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 45 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 46 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 47 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 48 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 49 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 50 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 51 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 52 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 53 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 54 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 55 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 56 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 57 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 58 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 59 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 60 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 61 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 62 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 63 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 64 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 65 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 66 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 67 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 68 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 69 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 70 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 71 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 72 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 73 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 74 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 75 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 76 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 77 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 78 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 79 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 80 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 81 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 82 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 83 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 84 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 85 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 86 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 87 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 88 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 89 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 90 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 91 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 92 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 93 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 94 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 95 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 96 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 97 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 98 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 99 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 100 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 101 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 102 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 103 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 104 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 105 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 106 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 107 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 108 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 109 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 110 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 111 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 112 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 113 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 114 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 115 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 116 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 117 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 118 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)

# %% [markdown]
# # Stage 2 optimization

# %%
model, x, f, jobs_sub, J, P, T = build_model(jobs)
run_schedule!(model, x, f, jobs_sub, J, P, T; stage1=true, stage2=true)
# Out:
# Stage 1: met 72 / 118  (solver time 4.71 s)
# Stage 1 makespan: 44.8 s
# Stage 1 throughput: 1.61 req/s
# Stage 1 # of GPU slots used: 436.0
# Stage 2: met 70 / 118  (solver time 33.24 s)
# Stage 2 makespan: 43.2 s
# Stage 2 throughput: 1.62 req/s
# Stage 2 # of GPU slots used: 428.0
#  • Job  1 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  2 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  3 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  4 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  5 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job  6 (shape 1024x1024) DID NOT COMPLETE (prog=3.29/16)
#  • Job  7 (shape  256x256 ) completed at slot   5 (4.00 s)  deadline=  5  met=yes
#  • Job  8 (shape  256x256 ) completed at slot   6 (4.80 s)  deadline=  6  met=yes
#  • Job  9 (shape  256x256 ) completed at slot   6 (4.80 s)  deadline=  6  met=yes
#  • Job 10 (shape  256x256 ) completed at slot   6 (4.80 s)  deadline=  6  met=yes
#  • Job 11 (shape  256x256 ) completed at slot   6 (4.80 s)  deadline=  6  met=yes
#  • Job 12 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 13 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 14 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 15 (shape 1024x1024) DID NOT COMPLETE (prog=10.69/16)
#  • Job 16 (shape  256x256 ) completed at slot  10 (8.00 s)  deadline= 10  met=yes
#  • Job 17 (shape  256x256 ) completed at slot  10 (8.00 s)  deadline= 10  met=yes
#  • Job 18 (shape  256x256 ) completed at slot   9 (7.20 s)  deadline= 10  met=yes
#  • Job 19 (shape  256x256 ) completed at slot   9 (7.20 s)  deadline= 10  met=yes
#  • Job 20 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 21 (shape  256x256 ) DID NOT COMPLETE (prog=3.00/4)
#  • Job 22 (shape  512x512 ) DID NOT COMPLETE (prog=2.00/5)
#  • Job 23 (shape  512x512 ) DID NOT COMPLETE (prog=2.00/5)
#  • Job 24 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 25 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 26 (shape  512x512 ) DID NOT COMPLETE (prog=1.00/5)
#  • Job 27 (shape  512x512 ) DID NOT COMPLETE (prog=1.00/5)
#  • Job 28 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 29 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 30 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 31 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 32 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 33 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 34 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 35 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 36 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 37 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 38 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 39 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 40 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 41 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 42 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 43 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 44 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 45 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 46 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 47 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 48 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 49 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 50 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 51 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 52 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 53 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 54 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 55 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 56 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 57 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 58 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 59 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 60 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 61 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 62 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 63 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 64 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 65 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 66 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 67 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 68 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 69 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 70 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 71 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 72 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 73 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 74 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 75 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 76 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 77 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 78 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 79 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 80 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 81 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 82 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 83 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 84 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 85 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 86 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 87 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 88 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 89 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 90 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 91 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 92 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 93 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 94 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 95 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 96 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 97 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 98 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 99 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 100 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 101 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 102 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 103 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 104 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 105 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 106 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 107 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 108 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 109 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 110 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 111 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 112 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 113 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 114 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 115 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 116 (shape  256x256 ) DID NOT COMPLETE (prog=0.00/4)
#  • Job 117 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 118 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)

# %% [markdown]
# # Stage 3 Optimization

# %%
model, x, f, jobs_sub, J, P, T = build_model(jobs)
run_schedule!(model, x, f, jobs_sub, J, P, T; stage1=true, stage2=true, stage3=true)
# Out:
# Stage 1: met 72 / 118  (solver time 5.1 s)
# Stage 1 makespan: 44.8 s
# Stage 1 throughput: 1.61 req/s
# ┌ Warning: The addition operator has been used on JuMP expressions a large number of times. This warning is safe to ignore but may indicate that model generation is slower than necessary. For performance reasons, you should not add expressions in a loop. Instead of x += y, use add_to_expression!(x,y) to modify x in place. If y is a single variable, you may also use add_to_expression!(x, coef, y) for x += coef*y.
# └ @ JuMP ~/.julia/packages/JuMP/CU7H5/src/operators.jl:282
# Stage 1 # of GPU slots used: 436.0
# Stage 2: met 70 / 118  (solver time 33.75 s)
# Stage 2 makespan: 43.2 s
# Stage 2 throughput: 1.62 req/s
# Stage 2 # of GPU slots used: 428.0
# Stage 3 makespan: 43.2 s
# Stage 3 throughput: 1.62 req/s
# Stage 3: met 70 / 118  (solver time 7.3 s)
# Stage 3 # of GPU slots used: 416.0
#  • Job  1 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  2 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  3 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  4 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  5 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job  6 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job  7 (shape  256x256 ) completed at slot   5 (4.00 s)  deadline=  5  met=yes
#  • Job  8 (shape  256x256 ) completed at slot   6 (4.80 s)  deadline=  6  met=yes
#  • Job  9 (shape  256x256 ) completed at slot   6 (4.80 s)  deadline=  6  met=yes
#  • Job 10 (shape  256x256 ) completed at slot   6 (4.80 s)  deadline=  6  met=yes
#  • Job 11 (shape  256x256 ) completed at slot   6 (4.80 s)  deadline=  6  met=yes
#  • Job 12 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 13 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 14 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 15 (shape 1024x1024) completed at slot  14 (11.20 s)  deadline= 14  met=yes
#  • Job 16 (shape  256x256 ) completed at slot  10 (8.00 s)  deadline= 10  met=yes
#  • Job 17 (shape  256x256 ) completed at slot  10 (8.00 s)  deadline= 10  met=yes
#  • Job 18 (shape  256x256 ) completed at slot   9 (7.20 s)  deadline= 10  met=yes
#  • Job 19 (shape  256x256 ) completed at slot   9 (7.20 s)  deadline= 10  met=yes
#  • Job 20 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 21 (shape  256x256 ) completed at slot  11 (8.80 s)  deadline= 12  met=yes
#  • Job 22 (shape  512x512 ) completed at slot  13 (10.40 s)  deadline= 13  met=yes
#  • Job 23 (shape  512x512 ) completed at slot  13 (10.40 s)  deadline= 13  met=yes
#  • Job 24 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 25 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 26 (shape  512x512 ) completed at slot  14 (11.20 s)  deadline= 14  met=yes
#  • Job 27 (shape  512x512 ) completed at slot  14 (11.20 s)  deadline= 14  met=yes
#  • Job 28 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 29 (shape  512x1024) completed at slot  17 (13.60 s)  deadline= 17  met=yes
#  • Job 30 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 31 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 32 (shape  256x256 ) completed at slot  16 (12.80 s)  deadline= 17  met=yes
#  • Job 33 (shape  256x256 ) completed at slot  17 (13.60 s)  deadline= 17  met=yes
#  • Job 34 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 35 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 36 (shape  256x256 ) completed at slot  18 (14.40 s)  deadline= 19  met=yes
#  • Job 37 (shape  256x256 ) completed at slot  18 (14.40 s)  deadline= 19  met=yes
#  • Job 38 (shape  256x256 ) completed at slot  18 (14.40 s)  deadline= 19  met=yes
#  • Job 39 (shape  256x256 ) completed at slot  18 (14.40 s)  deadline= 19  met=yes
#  • Job 40 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 41 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 42 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 43 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 44 (shape  512x512 ) completed at slot  21 (16.80 s)  deadline= 21  met=yes
#  • Job 45 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 46 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 47 (shape  256x256 ) completed at slot  23 (18.40 s)  deadline= 23  met=yes
#  • Job 48 (shape  256x256 ) completed at slot  23 (18.40 s)  deadline= 23  met=yes
#  • Job 49 (shape  256x256 ) completed at slot  23 (18.40 s)  deadline= 23  met=yes
#  • Job 50 (shape  256x256 ) completed at slot  23 (18.40 s)  deadline= 23  met=yes
#  • Job 51 (shape  256x256 ) completed at slot  22 (17.60 s)  deadline= 23  met=yes
#  • Job 52 (shape  256x256 ) completed at slot  23 (18.40 s)  deadline= 23  met=yes
#  • Job 53 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 54 (shape  512x512 ) completed at slot  23 (18.40 s)  deadline= 23  met=yes
#  • Job 55 (shape  512x512 ) completed at slot  24 (19.20 s)  deadline= 24  met=yes
#  • Job 56 (shape  512x512 ) completed at slot  24 (19.20 s)  deadline= 24  met=yes
#  • Job 57 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 58 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 59 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 60 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 61 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 62 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 63 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 64 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 65 (shape 2048x2048) DID NOT COMPLETE (prog=0.00/76)
#  • Job 66 (shape  512x1024) completed at slot  29 (23.20 s)  deadline= 29  met=yes
#  • Job 67 (shape  512x1024) DID NOT COMPLETE (prog=0.00/8)
#  • Job 68 (shape  512x1024) completed at slot  29 (23.20 s)  deadline= 29  met=yes
#  • Job 69 (shape  512x1024) completed at slot  29 (23.20 s)  deadline= 29  met=yes
#  • Job 70 (shape  256x256 ) completed at slot  28 (22.40 s)  deadline= 29  met=yes
#  • Job 71 (shape  256x256 ) completed at slot  30 (24.00 s)  deadline= 30  met=yes
#  • Job 72 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 73 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 74 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 75 (shape  512x512 ) completed at slot  33 (26.40 s)  deadline= 33  met=yes
#  • Job 76 (shape  512x512 ) completed at slot  33 (26.40 s)  deadline= 33  met=yes
#  • Job 77 (shape  256x256 ) completed at slot  34 (27.20 s)  deadline= 34  met=yes
#  • Job 78 (shape  256x256 ) completed at slot  33 (26.40 s)  deadline= 34  met=yes
#  • Job 79 (shape  256x256 ) completed at slot  34 (27.20 s)  deadline= 34  met=yes
#  • Job 80 (shape  256x256 ) completed at slot  33 (26.40 s)  deadline= 34  met=yes
#  • Job 81 (shape  256x256 ) completed at slot  36 (28.80 s)  deadline= 36  met=yes
#  • Job 82 (shape  256x256 ) completed at slot  36 (28.80 s)  deadline= 36  met=yes
#  • Job 83 (shape  256x256 ) completed at slot  36 (28.80 s)  deadline= 36  met=yes
#  • Job 84 (shape  256x256 ) completed at slot  36 (28.80 s)  deadline= 36  met=yes
#  • Job 85 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 86 (shape  256x256 ) completed at slot  38 (30.40 s)  deadline= 38  met=yes
#  • Job 87 (shape  256x256 ) completed at slot  38 (30.40 s)  deadline= 38  met=yes
#  • Job 88 (shape  256x256 ) completed at slot  38 (30.40 s)  deadline= 38  met=yes
#  • Job 89 (shape  256x256 ) completed at slot  38 (30.40 s)  deadline= 38  met=yes
#  • Job 90 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 91 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 92 (shape 1024x1024) completed at slot  45 (36.00 s)  deadline= 45  met=yes
#  • Job 93 (shape 1024x1024) completed at slot  45 (36.00 s)  deadline= 45  met=yes
#  • Job 94 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 95 (shape  512x512 ) completed at slot  40 (32.00 s)  deadline= 40  met=yes
#  • Job 96 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 97 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 98 (shape  512x512 ) completed at slot  44 (35.20 s)  deadline= 44  met=yes
#  • Job 99 (shape  512x512 ) completed at slot  45 (36.00 s)  deadline= 45  met=yes
#  • Job 100 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 101 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 102 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 103 (shape 1024x2048) DID NOT COMPLETE (prog=0.00/33)
#  • Job 104 (shape  256x256 ) completed at slot  48 (38.40 s)  deadline= 48  met=yes
#  • Job 105 (shape  256x256 ) completed at slot  48 (38.40 s)  deadline= 48  met=yes
#  • Job 106 (shape  256x256 ) completed at slot  48 (38.40 s)  deadline= 48  met=yes
#  • Job 107 (shape  256x256 ) completed at slot  47 (37.60 s)  deadline= 48  met=yes
#  • Job 108 (shape 1024x1024) completed at slot  54 (43.20 s)  deadline= 55  met=yes
#  • Job 109 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 110 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 111 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job 112 (shape  512x1024) completed at slot  52 (41.60 s)  deadline= 52  met=yes
#  • Job 113 (shape  512x1024) completed at slot  52 (41.60 s)  deadline= 52  met=yes
#  • Job 114 (shape  256x256 ) completed at slot  54 (43.20 s)  deadline= 54  met=yes
#  • Job 115 (shape  256x256 ) completed at slot  54 (43.20 s)  deadline= 54  met=yes
#  • Job 116 (shape  256x256 ) completed at slot  54 (43.20 s)  deadline= 54  met=yes
#  • Job 117 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)
#  • Job 118 (shape  512x512 ) DID NOT COMPLETE (prog=0.00/5)

# %% [markdown]
# # Show the runtime tradeoff with varying slot size

# %%
using CSV, DataFrames

results = DataFrame(slot_size=Float64[], solve_time=Float64[])

for Δ in 0.2:0.2:1.0
    println("------------------------------------------------")
    println("Slot size Δ = $Δ")

    model, x, f, jobs_sub, J, P, T = build_model(jobs)

    @objective(model, Max, sum(f[j] for j in J))

    t = solve_with_timelimit!(model; timelimit_s=60)

    push!(results, (Δ, t))
    println(" Solve time = $(round(t; digits=2)) s")
end

CSV.write("timings.csv", results)
# Out:
# ------------------------------------------------
# Slot size Δ = 0.2
#  Solve time = 5.06 s
# ------------------------------------------------
# Slot size Δ = 0.4
#  Solve time = 4.73 s
# ------------------------------------------------
# Slot size Δ = 0.6
#  Solve time = 4.77 s
# ------------------------------------------------
# Slot size Δ = 0.8
#  Solve time = 4.56 s
# ------------------------------------------------
# Slot size Δ = 1.0
#  Solve time = 4.52 s
# "timings.csv"

# %% [markdown]
# # Visualize the request placement for 8 requests

# %%
using CSV
model, x, f, jobs_sub, J, P, T_max = build_model(jobs, 8)

function save_placement(filename)
    rows = NamedTuple[]   # will hold (job,gpu,start_s,dur_s)
    for t in 0:T_max
        # collect (j, p_jt) for all jobs active at slot t
        active = []
        for j in J
            # find p such that x[j,p,t] = 1
            pj = findfirst(p->value(x[j,p,t]) > 0, P)
            if pj !== nothing
                push!(active, (j, pj))
            end
        end

        # sort by job ID (optional, just to be deterministic)
        sort!(active, by = first)

        # maintain a free‐GPU queue
        freeGPUs = collect(0:G-1)

        for (j, pj) in active
            # take the first pj GPUs
            assigned = freeGPUs[1:pj]
            freeGPUs = freeGPUs[(pj+1):end]
            # record each 0.2s slice
            for g in assigned
                push!(rows, (job=j-1, gpu=g, start_s=t*Δ, dur_s=Δ))
            end
        end
    end

    # write out
    CSV.write("$(filename).csv", rows)
end


run_schedule!(model, x, f, jobs_sub, J, P, T_max; stage1=true, stage2=false, stage3=false)
save_placement("schedule8_stage_1")
run_schedule!(model, x, f, jobs_sub, J, P, T_max; stage1=true, stage2=true, stage3=false)
save_placement("schedule8_stage_2")
model, x, f, jobs_sub, J, P, T_max = build_model(jobs, 8)
run_schedule!(model, x, f, jobs_sub, J, P, T_max; stage1=true, stage2=true, stage3=true)
save_placement("schedule8_stage_3")
# Out:
# Stage 1: met 8 / 8  (solver time 0.01 s)
# Stage 1 makespan: 8.0 s
# Stage 1 throughput: 1.0 req/s
# Stage 1 # of GPU slots used: 86.0
#  • Job  1 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  2 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  3 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  4 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  5 (shape 1024x1024) completed at slot  10 (8.00 s)  deadline= 10  met=yes
#  • Job  6 (shape 1024x1024) completed at slot  10 (8.00 s)  deadline= 10  met=yes
#  • Job  7 (shape  256x256 ) completed at slot   5 (4.00 s)  deadline=  5  met=yes
#  • Job  8 (shape  256x256 ) completed at slot   6 (4.80 s)  deadline=  6  met=yes
# Stage 1: met 8 / 8  (solver time 0.0 s)
# Stage 1 makespan: 8.0 s
# Stage 1 throughput: 1.0 req/s
# Stage 1 # of GPU slots used: 86.0
# Stage 2: met 6 / 8  (solver time 0.01 s)
# Stage 2 makespan: 4.0 s
# Stage 2 throughput: 1.5 req/s
# Stage 2 # of GPU slots used: 39.0
#  • Job  1 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  2 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  3 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  4 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  5 (shape 1024x1024) DID NOT COMPLETE (prog=4.20/16)
#  • Job  6 (shape 1024x1024) DID NOT COMPLETE (prog=5.20/16)
#  • Job  7 (shape  256x256 ) completed at slot   4 (3.20 s)  deadline=  5  met=yes
#  • Job  8 (shape  256x256 ) completed at slot   5 (4.00 s)  deadline=  6  met=yes
# Stage 1: met 8 / 8  (solver time 0.01 s)
# Stage 1 makespan: 8.0 s
# Stage 1 throughput: 1.0 req/s
# Stage 1 # of GPU slots used: 86.0
# Stage 2: met 6 / 8  (solver time 0.01 s)
# Stage 2 makespan: 4.0 s
# Stage 2 throughput: 1.5 req/s
# Stage 2 # of GPU slots used: 39.0
# Stage 3 makespan: 4.0 s
# Stage 3 throughput: 1.5 req/s
# Stage 3: met 6 / 8  (solver time 0.0 s)
# Stage 3 # of GPU slots used: 28.0
#  • Job  1 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  2 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  3 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  4 (shape  512x512 ) completed at slot   4 (3.20 s)  deadline=  4  met=yes
#  • Job  5 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job  6 (shape 1024x1024) DID NOT COMPLETE (prog=0.00/16)
#  • Job  7 (shape  256x256 ) completed at slot   5 (4.00 s)  deadline=  5  met=yes
#  • Job  8 (shape  256x256 ) completed at slot   5 (4.00 s)  deadline=  6  met=yes
# "schedule8_stage_3.csv"
